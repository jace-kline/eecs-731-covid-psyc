# %%
# General imports
import os
import re
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Import data
initial_data = '../data/initial/'

# Import dataset
df = pd.read_csv(initial_data + 'covid-anxiety-depression.csv')

# %%
df
# Out:
#       Phase                                          Indicator  \
# 0         1                    Symptoms of Depressive Disorder
# 1         1                    Symptoms of Depressive Disorder
# 2         1                    Symptoms of Depressive Disorder
# 3         1                    Symptoms of Depressive Disorder
# 4         1                    Symptoms of Depressive Disorder
# ...     ...                                                ...
# 3412      2  Symptoms of Anxiety Disorder or Depressive Dis...
# 3413      2  Symptoms of Anxiety Disorder or Depressive Dis...
# 3414      2  Symptoms of Anxiety Disorder or Depressive Dis...
# 3415      2  Symptoms of Anxiety Disorder or Depressive Dis...
# 3416      2  Symptoms of Anxiety Disorder or Depressive Dis...
#
#                   Group          State       Subgroup  Time Period  \
# 0     National Estimate  United States  United States            1
# 1                By Age  United States  18 - 29 years            1
# 2                By Age  United States  30 - 39 years            1
# 3                By Age  United States  40 - 49 years            1
# 4                By Age  United States  50 - 59 years            1
# ...                 ...            ...            ...          ...
# 3412           By State       Virginia       Virginia           16
# 3413           By State     Washington     Washington           16
# 3414           By State  West Virginia  West Virginia           16
# 3415           By State      Wisconsin      Wisconsin           16
# 3416           By State        Wyoming        Wyoming           16
#
#      Time Period Label  Value  Low CI  High CI Confidence Interval  \
# 0       Apr 23 - May 5   23.5    22.7     24.3         22.7 - 24.3
# 1       Apr 23 - May 5   32.7    30.2     35.2         30.2 - 35.2
# 2       Apr 23 - May 5   25.7    24.1     27.3         24.1 - 27.3
# 3       Apr 23 - May 5   24.8    23.3     26.2         23.3 - 26.2
# 4       Apr 23 - May 5   23.2    21.5     25.0         21.5 - 25.0
# ...                ...    ...     ...      ...                 ...
# 3412   Sep 30 - Oct 12   32.9    29.9     36.0         29.9 - 36.0
# 3413   Sep 30 - Oct 12   38.5    35.4     41.8         35.4 - 41.8
# 3414   Sep 30 - Oct 12   42.8    37.0     48.7         37.0 - 48.7
# 3415   Sep 30 - Oct 12   34.5    30.9     38.3         30.9 - 38.3
# 3416   Sep 30 - Oct 12   33.1    27.3     39.4         27.3 - 39.4
#
#      Quartile range
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3412      27.8-34.3
# 3413      36.7-38.8
# 3414      38.9-44.0
# 3415      34.4-36.6
# 3416      27.8-34.3
#
# [3417 rows x 12 columns]
